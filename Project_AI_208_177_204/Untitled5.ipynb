# %%
# !git clone https://github.com/huggingface/transformers \
&& cd transformers \
&& git checkout a3085020ed0d81d4903c50967687192e3101e770
# Out:
# fatal: destination path 'transformers' already exists and is not an empty directory.

# %%
# !pip3 install sentencepiece
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sentencepiece in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (0.2.1)
# WARNING: You are using pip version 21.2.4; however, version 25.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# !pip3 install transformers
# !pip3 install tensorboardX
# !pip3 install torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (4.55.0)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (from transformers) (0.6.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (from transformers) (0.21.4)
# Requirement already satisfied: packaging>=20.0 in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (from transformers) (25.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (from transformers) (2025.7.34)
# Requirement already satisfied: tqdm>=4.27 in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: filelock in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (from transformers) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (from transformers) (2.0.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (from transformers) (0.34.4)
# Requirement already satisfied: pyyaml>=5.1 in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: requests in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (from transformers) (2.32.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.7)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.14.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (2025.8.3)
# WARNING: You are using pip version 21.2.4; however, version 25.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorboardX in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (2.6.4)
# Requirement already satisfied: protobuf>=3.20 in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (from tensorboardX) (6.31.1)
# Requirement already satisfied: packaging in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (from tensorboardX) (25.0)
# Requirement already satisfied: numpy in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (from tensorboardX) (2.0.2)
# WARNING: You are using pip version 21.2.4; however, version 25.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (2.8.0)
# Requirement already satisfied: networkx in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (from torch) (3.2.1)
# Requirement already satisfied: fsspec in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (from torch) (2025.7.0)
# Requirement already satisfied: filelock in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (from torch) (4.14.1)
# Requirement already satisfied: jinja2 in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (from torch) (3.1.6)
# Requirement already satisfied: sympy>=1.13.3 in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (from torch) (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages (from jinja2->torch) (3.0.2)
# WARNING: You are using pip version 21.2.4; however, version 25.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import os
import torch
import time

from torch.utils.data import DataLoader, RandomSampler, SequentialSampler

from transformers import (
    AlbertConfig,
    AlbertForQuestionAnswering,
    AlbertTokenizer,
    squad_convert_examples_to_features
)

from transformers.data.processors.squad import SquadResult, SquadV2Processor, SquadExample

from transformers.data.metrics.squad_metrics import compute_predictions_logits

model_name_or_path = "ktrapeznikov/albert-xlarge-v2-squad-v2"

output_dir = ""

# Config
n_best_size = 1
max_answer_length = 50
do_lower_case = True
null_score_diff_threshold = 0.0

# Setup model
config_class, model_class, tokenizer_class = (
    AlbertConfig, AlbertForQuestionAnswering, AlbertTokenizer)
config = config_class.from_pretrained(model_name_or_path)
tokenizer = tokenizer_class.from_pretrained(
    model_name_or_path, do_lower_case=True)
model = model_class.from_pretrained(model_name_or_path, config=config)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model.to(device)

processor = SquadV2Processor()

def run_prediction(question_texts, context_text):
    """Setup function to compute predictions"""
    examples = []

    for i, question_text in enumerate(question_texts):
        example = SquadExample(
            qas_id=str(i),
            question_text=question_text,
            context_text=context_text,
            answer_text=None,
            start_position_character=None,
            title="Predict",
            is_impossible=False,
            answers=None,
        )

        examples.append(example)

    features, dataset = squad_convert_examples_to_features(
        examples=examples,
        tokenizer=tokenizer,
        max_seq_length=384,
        doc_stride=128,
        max_query_length=64,
        is_training=False,
        return_dataset="pt",
        threads=1,
    )

    eval_sampler = SequentialSampler(dataset)
    eval_dataloader = DataLoader(dataset, sampler=eval_sampler, batch_size=10)

    all_results = []

    for batch in eval_dataloader:
        model.eval()
        batch = tuple(t.to(device) for t in batch)

        with torch.no_grad():
            inputs = {
                "input_ids": batch[0],
                "attention_mask": batch[1],
                "token_type_ids": batch[2],
            }

            example_indices = batch[3]

            outputs = model(**inputs)

            for i, example_index in enumerate(example_indices):
                eval_feature = features[example_index.item()]
                unique_id = int(eval_feature.unique_id)

                if hasattr(outputs, "start_logits"):
                    start_logits = outputs.start_logits[i].detach().cpu().tolist()
                    end_logits = outputs.end_logits[i].detach().cpu().tolist()
                else:  
                    start_logits = outputs[0][i].detach().cpu().tolist()
                    end_logits = outputs[1][i].detach().cpu().tolist()
                result = SquadResult(unique_id, start_logits, end_logits)
                all_results.append(result)

    output_prediction_file = "predictions.json"
    output_nbest_file = "nbest_predictions.json"
    output_null_log_odds_file = "null_predictions.json"

    predictions = compute_predictions_logits(
        examples,
        features,
        all_results,
        n_best_size,
        max_answer_length,
        do_lower_case,
        output_prediction_file,
        output_nbest_file,
        output_null_log_odds_file,
        False,  
        True,  
        null_score_diff_threshold,
        tokenizer,
    )

    return predictions
# Out:
# Some weights of the model checkpoint at ktrapeznikov/albert-xlarge-v2-squad-v2 were not used when initializing AlbertForQuestionAnswering: ['albert.pooler.bias', 'albert.pooler.weight']
# - This IS expected if you are initializing AlbertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
context = "Delhi Technological University (Delhi College of Engineering) operated from the Kashmiri Gate campus in the heart of Old Delhi until 1989, when construction began at the New Campus at Bawana Road in May. Moving of operations from Kashmiri Gate to the new 164 acres at Bawana Road began in 1995, and the new campus formally started classes for all four years of study starting 1999."

questions = ["Where is kashmiri gate?", 
             "Where is Delhi Technological University's new campus?"]

# Run method
predictions = run_prediction(questions, context)

# Print results
for key in predictions.keys():
  print(predictions[key])
# Out:
# convert squad examples to features:   0%|          | 0/2 [00:00<?, ?it/s]/Users/srikarvadlamani/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# convert squad examples to features: 100%|██████████| 2/2 [00:01<00:00,  1.37it/s]
# add example index and unique id: 100%|██████████| 2/2 [00:00<00:00, 53773.13it/s]
# in the heart of Old Delhi
# Bawana Road
